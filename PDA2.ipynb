# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Lab_2_BEML_gain.csv')

# %%
data
# Out:
#             Date    Close      Gain
# 0     2010-01-05  1134.60 -0.000881
# 1     2010-01-06  1139.60  0.004407
# 2     2010-01-07  1144.15  0.003993
# 3     2010-01-08  1144.05 -0.000087
# 4     2010-01-11  1137.00 -0.006162
# ...          ...      ...       ...
# 1733  2016-12-26   950.25 -0.021924
# 1734  2016-12-27   975.70  0.026782
# 1735  2016-12-28   974.40 -0.001332
# 1736  2016-12-29   986.05  0.011956
# 1737  2016-12-30  1000.60  0.014756
#
# [1738 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1738 entries, 0 to 1737
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1738 non-null   object
#  1   Close   1738 non-null   float64
#  2   Gain    1738 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 40.9+ KB

# %%
data['daily_return'] = data['Close'].pct_change()

# %%
data
# Out:
#             Date    Close      Gain  daily_return
# 0     2010-01-05  1134.60 -0.000881           NaN
# 1     2010-01-06  1139.60  0.004407      0.004407
# 2     2010-01-07  1144.15  0.003993      0.003993
# 3     2010-01-08  1144.05 -0.000087     -0.000087
# 4     2010-01-11  1137.00 -0.006162     -0.006162
# ...          ...      ...       ...           ...
# 1733  2016-12-26   950.25 -0.021924     -0.021924
# 1734  2016-12-27   975.70  0.026782      0.026782
# 1735  2016-12-28   974.40 -0.001332     -0.001332
# 1736  2016-12-29   986.05  0.011956      0.011956
# 1737  2016-12-30  1000.60  0.014756      0.014756
#
# [1738 rows x 4 columns]

# %%
prob_gain_3_percent = np.sum(data['daily_return'] >= 0.03) / len(data)
prob_loss_2_percent = np.sum(data['daily_return'] <= -0.02) / len(data)

# %%
print(f'Probability of making a daily return of 3% or more: {prob_gain_3_percent}')
print(f'Probability of making a loss of 2% or more: {prob_loss_2_percent}')
# Out:
# Probability of making a daily return of 3% or more: 0.09090909090909091
# Probability of making a loss of 2% or more: 0.1622554660529344
